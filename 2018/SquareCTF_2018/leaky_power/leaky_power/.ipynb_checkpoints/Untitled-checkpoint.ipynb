# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
pt = np.load("plaintexts.npy")
traces = np.load("powertraces.npy") ; traces
# Out:
# array([[ 0.05371094,  0.03222656,  0.09960938, ...,  0.04101562,
#          0.11914062, -0.14355469],
#        [ 0.04003906,  0.02148438,  0.09082031, ...,  0.04492188,
#          0.12304688, -0.13183594],
#        [ 0.04785156,  0.02832031,  0.09472656, ...,  0.04589844,
#          0.12304688, -0.14648438],
#        ...,
#        [ 0.05273438,  0.03027344,  0.09863281, ...,  0.04394531,
#          0.12011719, -0.14257812],
#        [ 0.04394531,  0.02441406,  0.09277344, ...,  0.04003906,
#          0.11816406, -0.14257812],
#        [ 0.04785156,  0.02636719,  0.09570312, ...,  0.04003906,
#          0.11816406, -0.15136719]])

# %%
plt.plot(traces[0])
plt.show()
